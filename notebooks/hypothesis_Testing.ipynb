# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.path.dirname('__file__'), '..')))

# %%
from src.services.hypothesis_test import Test

# %%
test = Test()

# %%
test.load_data("../data/processed/insurance_clean.csv")
# Out:
# e:\AI\Week-3\Week-3 Project\Insurance_Risk_Analytics\src\services\hypothesis_test.py:8: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_csv(file_path)

# %%
#  Province comparison
province_results = test.test_all_province_pairs()
for result in province_results:
    test.generate_report(result)
# Out:
# 📌 Hypothesis: Risk differences across provinces
# Comparing Gauteng vs Kwazulu-Natal
#   claim_frequency_p: 0.0021 ➤ REJECT the null hypothesis.
#   claim_severity_p: 0.0005 ➤ REJECT the null hypothesis.
#
# 📌 Hypothesis: Risk differences across provinces
# Comparing Gauteng vs Mpumalanga
#   claim_frequency_p: 0.0003 ➤ REJECT the null hypothesis.
#   claim_severity_p: 0.0303 ➤ REJECT the null hypothesis.
#
# 📌 Hypothesis: Risk differences across provinces
# Comparing Gauteng vs Eastern Cape
#   claim_frequency_p: 0.0000 ➤ REJECT the null hypothesis.
#   claim_severity_p: 0.4965 ➤ FAIL TO REJECT the null hypothesis.
#
# 📌 Hypothesis: Risk differences across provinces
# Comparing Gauteng vs Western Cape
#   claim_frequency_p: 0.0000 ➤ REJECT the null hypothesis.
#   claim_severity_p: 0.0267 ➤ REJECT the null hypothesis.
#
# 📌 Hypothesis: Risk differences across provinces
# Comparing Gauteng vs Limpopo
#   claim_frequency_p: 0.0768 ➤ FAIL TO REJECT the null hypothesis.
# ...

# %%
 #Zip code comparison
zipcode_results = test.test_all_zipcode_pairs()
for result in zipcode_results:
    test.generate_report(result)
# Out:
# 📌 Hypothesis: Risk differences across zip codes
# Comparing 2000 vs 122
#   claim_frequency_p: 0.0579 ➤ FAIL TO REJECT the null hypothesis.
#   claim_severity_p: 0.7002 ➤ FAIL TO REJECT the null hypothesis.
#
# 📌 Hypothesis: Risk differences across zip codes
# Comparing 2000 vs 7784
#   claim_frequency_p: 0.0000 ➤ REJECT the null hypothesis.
#   claim_severity_p: 0.0558 ➤ FAIL TO REJECT the null hypothesis.
#
# 📌 Hypothesis: Risk differences across zip codes
# Comparing 2000 vs 299
#   claim_frequency_p: 0.0134 ➤ REJECT the null hypothesis.
#   claim_severity_p: 0.0573 ➤ FAIL TO REJECT the null hypothesis.
#
# 📌 Hypothesis: Risk differences across zip codes
# Comparing 2000 vs 7405
#   claim_frequency_p: 0.0000 ➤ REJECT the null hypothesis.
#   claim_severity_p: 0.5844 ➤ FAIL TO REJECT the null hypothesis.
#
# 📌 Hypothesis: Risk differences across zip codes
# Comparing 122 vs 7784
#   claim_frequency_p: 0.0000 ➤ REJECT the null hypothesis.
# ...

# %%
# zip margin comparisons
margin_results = test.test_all_zipcode_margin_pairs()
for r in margin_results:
    test.generate_report(r)
# Out:
# 📌 Hypothesis: Margin differences across zip codes
# Comparing 2000 vs 122
#   margin_p: 0.2445 ➤ FAIL TO REJECT the null hypothesis.
#
# 📌 Hypothesis: Margin differences across zip codes
# Comparing 2000 vs 7784
#   margin_p: 0.7565 ➤ FAIL TO REJECT the null hypothesis.
#
# 📌 Hypothesis: Margin differences across zip codes
# Comparing 2000 vs 299
#   margin_p: 0.0046 ➤ REJECT the null hypothesis.
#
# 📌 Hypothesis: Margin differences across zip codes
# Comparing 2000 vs 7405
#   margin_p: 0.0066 ➤ REJECT the null hypothesis.
#
# 📌 Hypothesis: Margin differences across zip codes
# Comparing 122 vs 7784
#   margin_p: 0.6383 ➤ FAIL TO REJECT the null hypothesis.
#
# 📌 Hypothesis: Margin differences across zip codes
# Comparing 122 vs 299
#   margin_p: 0.0024 ➤ REJECT the null hypothesis.
#
# 📌 Hypothesis: Margin differences across zip codes
# Comparing 122 vs 7405
#   margin_p: 0.0033 ➤ REJECT the null hypothesis.
#
# 📌 Hypothesis: Margin differences across zip codes
# ...

# %%
# gender comparison
gender_result = test.test_gender_risk()
test.generate_report(gender_result)
# Out:
# 📌 Hypothesis: Risk differences by gender
# Comparing male vs female
#   claim_frequency_p: 0.9515 ➤ FAIL TO REJECT the null hypothesis.
#   claim_severity_p: 0.5680 ➤ FAIL TO REJECT the null hypothesis.
